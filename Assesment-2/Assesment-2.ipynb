# %% [markdown]
# # Assesment 2

# %%
# Task 1: Printing a Message

print('Hello, everyone! I am learning Python. 😄')
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
# Task 2: Declaring Variables

name = "Misbah Hafeez"
age = 22
favourite_animal = "Cat"
print("Name =" , name)
print("Age = " , age)
print("Favourite Animal = " , favourite_animal)
# Out:
# Name = Misbah Hafeez
# Age =  22
# Favourite Animal =  Cat

# %%
# Task 3: Combining Variables in a Message

name = "Misbah Hafeez"
age = 22
favourite_animal = "Cat"
print(f'My name is {name} , and I am {age} years old , and I love {favourite_animal}')
# Out:
# My name is Misbah Hafeez , and I am 22 years old , and I love Cat

# %%
# Task 4: Playing with Different Data Types
favourite_movie : str = "Story"
birth_year : int = 2003
fav_snack_price : float = 100.6
print("Favourite Movie =", favourite_movie)
print("Birth Year =", birth_year)
print("Price of Snack =" , fav_snack_price)
# Out:
# Favourite Movie = Story
# Birth Year = 2003
# Price of Snack = 100.6

# %%
# Task 5: Your Favorite Hobby
hobby = "reading books"
print("My favourite hobby is {0}".format(hobby))
# Out:
# My favourite hobby is reading books

# %%
# Extra Challenge
a = 6
b = 8
c = a + b
print("a =", a)
print("b =", b)
print("c =", c)
# Out:
# a = 6
# b = 8
# c = 14
