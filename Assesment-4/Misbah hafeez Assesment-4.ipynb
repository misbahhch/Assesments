# %% [markdown]
# # Assesment 4

# %%
num1 = int(input("Enter a number : "))
# Out:
# Enter a number :  345

# %%
digit1 = num//100
print(digit1)
# Out:
# 3

# %%
digit2 =(num//10)%10
print(digit2)
# Out:
# 4

# %%
digit3 = num%10
print(digit3)
# Out:
# 5

# %%
sum = digit1 +digit2 + digit3

# %%
print("Sum : ",sum)
# Out:
# Sum :  12
