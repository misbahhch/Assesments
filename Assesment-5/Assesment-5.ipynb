# %% [markdown]
# # 1. Prompt for user input

# %%
name = str(input("Enter full name :"))
print(f"Hello,{name}! Welcome to the Python assignment.")
# Out:
# Enter full name : Misbah Hafeez
# Hello,Misbah Hafeez! Welcome to the Python assignment.

# %% [markdown]
# # 2. String methods

# %%
# Print the user’s name in all uppercase letters.
user_name = str(input("Enter full name :"))
print("name in uppercase:",user_name.upper())
# Out:
# Enter full name : Misbah hafeez
# name in uppercase: MISBAH HAFEEZ

# %%
# Print the user’s name in all lowercase letters.
print("name in lowercase:",user_name.lower())
# Out:
# name in lowercase: misbah hafeez

# %%
# Print the length of the user’s name (number of characters).
print("Length of name:",len(user_name))
# Out:
# Length of name: 13

# %%
# Replace all the spaces in the user’s name with hyphens (-), and print the result.
result = "-".join(user_name.split())
print("Name with hyphens:",result)
# Out:
# Name with hyphens: Misbah-hafeez

# %%
# Bonus: Trim any leading or trailing spaces (if any) from the user’s name using strip().
name1 = str(input("Enter full name :"))
user_name.strip()
# Out:
# Enter full name :    Misbah hafeez
# 'Misbah hafeez'

# %% [markdown]
# # Type casting and numeric operations

# %%
# Ask the user to enter their birth year (as input). Convert that input to an integer.
# Calculate the user’s approximate age by subtracting the birth year from the current year. Print the result in a sentence
birth_year = int(input("Enter your birth year :"))
current_year = 2026
Age = current_year - birth_year 
print(f"Your are approximately {Age} years old")
# Out:
# Enter your birth year : 2003
# Your are approximately 23 years old

# %% [markdown]
# # Part 2: Lists and Indexing

# %%
# Prompt the user to enter three of their favorite fruits (e.g., "apple,banana,orange") in one line, separated by commas.
#Split the string by commas to create a list called fruit_list.
#Print the list to verify that it’s correct.

fav_fruits = str(input("Enter three fav fruit :"))
fruits = fav_fruits.split()
print(f'List of fruits : {fruits}')
# Out:
# Enter three fav fruit : apple banana orange
# List of fruits : ['apple', 'banana', 'orange']

# %%
#Print the first fruit in the list.
#Print the last fruit in the list.
#Print the second fruit in the list using indexing (i.e., fruit_list[1]).
#Print the slice of the list containing the first two fruits.

print(f"First Fruit :{fruits[0]}")
print(f"Last Fruit {fruits[-1]}")
print(f"Second Fruit :{fruits[1]}")
print(f"First two fruits :{fruits[0:2]}")
# Out:
# First Fruit :apple
# Last Fruit orange
# Second Fruit :banana
# First two fruits :['apple', 'banana']

# %%
# Append a new fruit to the list using append(). Print the updated list.
# Remove one fruit from the list using remove() (or pop()). Print the updated list again.
# Print the length of the list using len().
fruits.append("kiwi")
print(f"Updated List :{fruits}")
fruits.pop(1)
print(f"Updated List :{fruits}")
print(f"Length of the list :{len(fruits)}")
# Out:
# Updated List :['apple', 'banana', 'orange', 'kiwi']
# Updated List :['apple', 'orange', 'kiwi']
# Length of the list :3

# %% [markdown]
# # Part 3 : Combining Concepts

# %%
# Create a new list from the letters of your full_name (excluding spaces).
#Hint:
#letters_list = list(full_name.replace(" ", ""))
#Print the first 3 letters and the last 3 letters of letters_list.
full_name = str(input("Enter full_name:"))
letter_list = list(full_name.replace(" ",""))
print(f"First three letter : {letter_list[0:3]}")
print(f"Last three letter : {letter_list[-3:]}")
# Out:
# Enter full_name: Misbahhafeez
# First three letter : ['M', 'i', 's']
# Last three letter : ['e', 'e', 'z']

# %%
## Convert the first 3 letters of letters_list to uppercase, and the rest to lowercase.
##Reconstruct the name from letters_list back into a string using "".join(...) and print it out.
letter_list[:3]= full_name[:3].upper()
letter_list[3:]=full_name[3:].lower()
result = "".join(letter_list)
print(f"Modified name:{result}")
# Out:
# Modified name:MISbahhafeez

# %%
# Prompt the user to enter 5 numbers (e.g., "10 20 30 40 50") in one line, separated by spaces.
#Convert each input into an integer and store all in a list called numbers_list.
#Print the sum of the numbers, and the average (sum / length of the list).
num = input("Enter five numbers :")

numbers_list = num.split()
Sum = int(numbers_list[0])+int( numbers_list[1])+int(numbers_list[2])+int(numbers_list[3])+int(numbers_list[4])
print(f"Sum :{Sum}")
Average = Sum/len(numbers_list)
print(f"Average :{Average}")
# Out:
# Enter five numbers : 10 20 30 40 50
# Sum :150
# Average :30.0
